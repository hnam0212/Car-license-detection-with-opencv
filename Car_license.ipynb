# %%
# !pip install opencv-python
# !pip install imutils
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.5.4.60-cp39-cp39-win_amd64.whl (35.1 MB)
# Collecting numpy>=1.19.3
#   Using cached numpy-1.21.4-cp39-cp39-win_amd64.whl (14.0 MB)
# WARNING: You are using pip version 21.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'D:\learning stuff\OPENCV\ocv\Scripts\python.exe -m pip install --upgrade pip' command.
# Installing collected packages: numpy, opencv-python
# Successfully installed numpy-1.21.4 opencv-python-4.5.4.60
# Collecting imutils
#   Using cached imutils-0.5.4-py3-none-any.whl
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4
# WARNING: You are using pip version 21.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'D:\learning stuff\OPENCV\ocv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
import imutils

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.5.0-cp39-cp39-win_amd64.whl (7.2 MB)
# Collecting packaging>=20.0
#   Downloading packaging-21.3-py3-none-any.whl (40 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.28.2-py3-none-any.whl (880 kB)
# Requirement already satisfied: numpy>=1.17 in d:\learning stuff\opencv\ocv\lib\site-packages (from matplotlib) (1.21.4)
# Collecting pillow>=6.2.0
#   Using cached Pillow-8.4.0-cp39-cp39-win_amd64.whl (3.2 MB)
# Requirement already satisfied: python-dateutil>=2.7 in d:\learning stuff\opencv\ocv\lib\site-packages (from matplotlib) (2.8.2)
# Collecting setuptools-scm>=4
#   Downloading setuptools_scm-6.3.2-py3-none-any.whl (33 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.3.2-cp39-cp39-win_amd64.whl (52 kB)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-3.0.6-py3-none-any.whl (97 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: six>=1.5 in d:\learning stuff\opencv\ocv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 21.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'D:\learning stuff\OPENCV\ocv\Scripts\python.exe -m pip install --upgrade pip' command.
# Collecting tomli>=1.0.0
#   Downloading tomli-1.2.2-py3-none-any.whl (12 kB)
# Requirement already satisfied: setuptools in d:\learning stuff\opencv\ocv\lib\site-packages (from setuptools-scm>=4->matplotlib) (57.4.0)
# Installing collected packages: pyparsing, tomli, packaging, setuptools-scm, pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.28.2 kiwisolver-1.3.2 matplotlib-3.5.0 packaging-21.3 pillow-8.4.0 pyparsing-3.0.6 setuptools-scm-6.3.2 tomli-1.2.2

# %%
from matplotlib import pyplot as plt

# %%
img=cv2.imread("image1.jpg")
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %%
bfilter=cv2.bilateralFilter(gray,10,20,20)
edge=cv2.Canny(bfilter,50,220)
plt.imshow(cv2.cvtColor(edge, cv2.COLOR_BGR2RGB))

# %%
keypoints=cv2.findContours(edge.copy(),cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
contours= imutils.grab_contours(keypoints)
print(len(contours))
# Out:
# 207

# %%
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]
print(len(contours))
# Out:
# 10

# %%
location =None
for contour in contours:
    approx = cv2.approxPolyDP(contour,10,True)
    if len(approx) == 4:
        location = approx
        break

# %%
location
# Out:
# array([[[251,  97]],
#
#        [[104, 126]],
#
#        [[ 93,  79]],
#
#        [[234,  64]]], dtype=int32)

# %%
import numpy as np
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0,255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(new_image)

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in d:\learning stuff\opencv\ocv\lib\site-packages (21.2.3)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
#     WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# Collecting pip
#   Using cached pip-21.3.1-py3-none-any.whl (1.7 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.3
#     Uninstalling pip-21.2.3:
#       Successfully uninstalled pip-21.2.3
# Successfully installed pip-21.3.1

# %%
# !pip install easyocr
# Out:
# Collecting easyocr
#   Using cached easyocr-1.4.1-py3-none-any.whl (63.6 MB)
# Collecting opencv-python-headless
#   Using cached opencv_python_headless-4.5.4.60-cp39-cp39-win_amd64.whl (35.0 MB)
# Requirement already satisfied: torch in d:\learning stuff\opencv\ocv\lib\site-packages (from easyocr) (1.10.0)
# Requirement already satisfied: torchvision>=0.5 in d:\learning stuff\opencv\ocv\lib\site-packages (from easyocr) (0.11.1)
# Requirement already satisfied: numpy in d:\learning stuff\opencv\ocv\lib\site-packages (from easyocr) (1.21.4)
# Requirement already satisfied: PyYAML in d:\learning stuff\opencv\ocv\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: Pillow<8.3.0 in d:\learning stuff\opencv\ocv\lib\site-packages (from easyocr) (8.2.0)
# Requirement already satisfied: scikit-image in d:\learning stuff\opencv\ocv\lib\site-packages (from easyocr) (0.18.3)
# Requirement already satisfied: scipy in d:\learning stuff\opencv\ocv\lib\site-packages (from easyocr) (1.7.3)
# Requirement already satisfied: python-bidi in d:\learning stuff\opencv\ocv\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: typing-extensions in d:\learning stuff\opencv\ocv\lib\site-packages (from torch->easyocr) (4.0.1)
# Requirement already satisfied: six in d:\learning stuff\opencv\ocv\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: networkx>=2.0 in d:\learning stuff\opencv\ocv\lib\site-packages (from scikit-image->easyocr) (2.6.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in d:\learning stuff\opencv\ocv\lib\site-packages (from scikit-image->easyocr) (1.2.0)
# Requirement already satisfied: imageio>=2.3.0 in d:\learning stuff\opencv\ocv\lib\site-packages (from scikit-image->easyocr) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in d:\learning stuff\opencv\ocv\lib\site-packages (from scikit-image->easyocr) (2021.11.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in d:\learning stuff\opencv\ocv\lib\site-packages (from scikit-image->easyocr) (3.5.0)
# Requirement already satisfied: packaging>=20.0 in d:\learning stuff\opencv\ocv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (21.3)
# Requirement already satisfied: setuptools-scm>=4 in d:\learning stuff\opencv\ocv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (6.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\learning stuff\opencv\ocv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in d:\learning stuff\opencv\ocv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\learning stuff\opencv\ocv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (3.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in d:\learning stuff\opencv\ocv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (4.28.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\learning stuff\opencv\ocv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (1.3.2)
# Requirement already satisfied: tomli>=1.0.0 in d:\learning stuff\opencv\ocv\lib\site-packages (from setuptools-scm>=4->matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (1.2.2)
# Requirement already satisfied: setuptools in d:\learning stuff\opencv\ocv\lib\site-packages (from setuptools-scm>=4->matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (57.4.0)
# Installing collected packages: opencv-python-headless, easyocr
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'D:\\learning stuff\\OPENCV\\ocv\\Lib\\site-packages\\cv2\\cv2.cp39-win_amd64.pyd'
# Check the permissions.
#
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)

# %%
# !pip3 install torch torchvision torchaudio
# Out:
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (d:\learning stuff\opencv\ocv\lib\site-packages)
# WARNING: You are using pip version 21.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'D:\learning stuff\OPENCV\ocv\Scripts\python.exe -m pip install --upgrade pip' command.
# Collecting torch
#   Using cached torch-1.10.0-cp39-cp39-win_amd64.whl (226.5 MB)
# Collecting torchvision
#   Using cached torchvision-0.11.1-cp39-cp39-win_amd64.whl (984 kB)
# Collecting torchaudio
#   Downloading torchaudio-0.10.0-cp39-cp39-win_amd64.whl (341 kB)
# Requirement already satisfied: typing-extensions in d:\learning stuff\opencv\ocv\lib\site-packages (from torch) (4.0.1)
# Requirement already satisfied: numpy in d:\learning stuff\opencv\ocv\lib\site-packages (from torchvision) (1.21.4)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in d:\learning stuff\opencv\ocv\lib\site-packages (from torchvision) (8.2.0)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-1.10.0 torchaudio-0.10.0 torchvision-0.11.1

# %%
import easyocr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20876/3640170844.py in <module>
# ----> 1 import easyocr
#
# ModuleNotFoundError: No module named 'easyocr'
